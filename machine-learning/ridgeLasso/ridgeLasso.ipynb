# %% [markdown]
# # This Notebook contains sample code to demonstrate how to use the LR/MLR | Ridge Regression model/ Lasso & ElasticNet after successfully peroforming EDA and feature engineering.

# %% [markdown]
# # Algerian Forest Fires Dataset
#
# The dataset includes 244 instances that regroup a data of two regions of Algeria, namely the Bejaia region located in the northeast of Algeria and the Sidi Bel-abbes region located in the northwest of Algeria.
#
# 122 instances for each region.
#
# The period from June 2012 to September 2012.
# The dataset includes 11 attributes and 1 output attribute (class)
# The 244 instances have been classified into fire (138 classes) and not fire (106 classes) classes.
#
# - source : https://www.kaggle.com/datasets/nitinchoudhary012/algerian-forest-fires-dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# reading the dataset

df = pd.read_csv("Algerian_forest_fires_dataset.csv")

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0   1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1   2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2   3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3   4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4   5     6  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %%
df.columns = df.columns.str.strip()

# %%
df.shape
# Out:
# (247, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4   RH           245 non-null    object
#  5   Ws           245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
# dtypes: object(14)
# memory usage: 27.1+ KB

# %%
#missing values
df.isnull().sum()
# Out:
# day            1
# month          2
# year           2
# Temperature    2
# RH             2
# Ws             2
# Rain           2
# FFMC           2
# DMC            2
# DC             2
# ISI            2
# BUI            2
# FWI            2
# Classes        3
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#                                day month  year Temperature   RH   Ws Rain  \
# 122                            NaN   NaN   NaN         NaN  NaN  NaN  NaN
# 123  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN  NaN
# 168                             14     7  2012          37   37   18  0.2
#
#      FFMC   DMC      DC   ISI   BUI      FWI Classes
# 122   NaN   NaN     NaN   NaN   NaN      NaN     NaN
# 123   NaN   NaN     NaN   NaN   NaN      NaN     NaN
# 168  88.9  12.9  14.6 9  12.5  10.4  fire        NaN

# %%
# create new columns for the two regions

df.loc[:122,"Region"]=0
df.loc[122:,"Region"]=1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4   RH           245 non-null    object
#  5   Ws           245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
#  14  Region       247 non-null    float64
# dtypes: float64(1), object(14)
# memory usage: 29.1+ KB

# %%
df[['Region']]=df[['Region']].astype(int)

# %%
df.isnull().sum()
# Out:
# day            1
# month          2
# year           2
# Temperature    2
# RH             2
# Ws             2
# Rain           2
# FFMC           2
# DMC            2
# DC             2
# ISI            2
# BUI            2
# FWI            2
# Classes        3
# Region         0
# dtype: int64

# %%
#Remove the null values
df=df.dropna().reset_index(drop=True)

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  \
# 0   1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1   2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2   3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3   4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4   5     6  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#        Classes  Region
# 0  not fire          0
# 1  not fire          0
# 2  not fire          0
# 3  not fire          0
# 4  not fire          0

# %%
df.iloc[[122]]
# Out:
#      day  month  year  Temperature   RH   Ws   Rain  FFMC  DMC  DC  ISI  BUI  \
# 122  day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI
#
#      FWI    Classes  Region
# 122  FWI  Classes         1

# %%
df=df.drop(122).reset_index(drop=True)

# %%
df.iloc[[122]]
# Out:
#     day month  year Temperature  RH  Ws Rain  FFMC  DMC   DC  ISI  BUI  FWI  \
# 122   1     6  2012          32  71  12  0.7  57.1  2.5  8.2  0.6  2.8  0.2
#
#          Classes  Region
# 122  not fire          1

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
# changing some columns's datatype into integer
df[['month','day','year','Temperature','RH','Ws']] = df[['month','day','year','Temperature','RH','Ws']].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int64
#  1   month        243 non-null    int64
#  2   year         243 non-null    int64
#  3   Temperature  243 non-null    int64
#  4   RH           243 non-null    int64
#  5   Ws           243 non-null    int64
#  6   Rain         243 non-null    object
#  7   FFMC         243 non-null    object
#  8   DMC          243 non-null    object
#  9   DC           243 non-null    object
#  10  ISI          243 non-null    object
#  11  BUI          243 non-null    object
#  12  FWI          243 non-null    object
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int64
# dtypes: int64(7), object(8)
# memory usage: 28.6+ KB

# %%
# changing the remaining columns to float datatype
df[['month','day','year','Temperature','RH','Ws']] = df[['month','day','year','Temperature','RH','Ws']].astype(int)

# %%
df[['Rain', 'FFMC','DMC', 'DC', 'ISI', 'BUI', 'FWI']]=df[['Rain', 'FFMC','DMC', 'DC', 'ISI', 'BUI', 'FWI']].astype(float)  

# objects = [features for features indf.columns if df[features].dtypes=='O']
# for i in objects:
    # if i != 'Classes':
       # df[i] = df[i].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int64
#  1   month        243 non-null    int64
#  2   year         243 non-null    int64
#  3   Temperature  243 non-null    int64
#  4   RH           243 non-null    int64
#  5   Ws           243 non-null    int64
#  6   Rain         243 non-null    float64
#  7   FFMC         243 non-null    float64
#  8   DMC          243 non-null    float64
#  9   DC           243 non-null    float64
#  10  ISI          243 non-null    float64
#  11  BUI          243 non-null    float64
#  12  FWI          243 non-null    float64
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int64
# dtypes: float64(7), int64(7), object(1)
# memory usage: 28.6+ KB

# %%
df.describe()
# Out:
#               day       month    year  Temperature          RH          Ws  \
# count  243.000000  243.000000   243.0   243.000000  243.000000  243.000000
# mean    15.761317    7.502058  2012.0    32.152263   62.041152   15.493827
# std      8.842552    1.114793     0.0     3.628039   14.828160    2.811385
# min      1.000000    6.000000  2012.0    22.000000   21.000000    6.000000
# 25%      8.000000    7.000000  2012.0    30.000000   52.500000   14.000000
# 50%     16.000000    8.000000  2012.0    32.000000   63.000000   15.000000
# 75%     23.000000    8.000000  2012.0    35.000000   73.500000   17.000000
# max     31.000000    9.000000  2012.0    42.000000   90.000000   29.000000
#
#              Rain        FFMC         DMC          DC         ISI         BUI  \
# count  243.000000  243.000000  243.000000  243.000000  243.000000  243.000000
# mean     0.762963   77.842387   14.680658   49.430864    4.742387   16.690535
# ...

# %%
df.to_csv("fires_dataset_cleaned.csv", index=False)

# %% [markdown]
# # EDA

# %%
df_copy = df.drop(['day','month','year'],axis=1)

# %%
df_copy.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI      Classes  \
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5  not fire
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4  not fire
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1  not fire
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0  not fire
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5  not fire
#
#    Region
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df_copy['Classes'].value_counts()
# Out:
# Classes
# fire             131
# not fire         101
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: count, dtype: int64

# %%
# Encoding of the categories in classes
df_copy['Classes'] = np.where(df_copy['Classes'].str.contains('not fire'),0,1)

# %%
df_copy
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  Classes  \
# 0             29  57  18   0.0  65.7   3.4   7.6  1.3   3.4  0.5        0
# 1             29  61  13   1.3  64.4   4.1   7.6  1.0   3.9  0.4        0
# 2             26  82  22  13.1  47.1   2.5   7.1  0.3   2.7  0.1        0
# 3             25  89  13   2.5  28.6   1.3   6.9  0.0   1.7  0.0        0
# 4             27  77  16   0.0  64.8   3.0  14.2  1.2   3.9  0.5        0
# ..           ...  ..  ..   ...   ...   ...   ...  ...   ...  ...      ...
# 238           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5        1
# 239           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2  0.0        0
# 240           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2        0
# 241           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7        0
# 242           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5        0
#
#      Region
# 0         0
# 1         0
# 2         0
# 3         0
# ...

# %% [markdown]
# # Visualizations

# %%
#pie chart
percentage = df_copy['Classes'].value_counts(normalize=True)*100
chart_labels = ["Fire","Not fire"]
plt.figure(figsize = (12,7))
plt.pie(percentage,labels=chart_labels,autopct='%1.1f%%')
plt.title("Pie chart for Classes")
# Out:
# Text(0.5, 1.0, 'Pie chart for Classes')

# %%
# desnity plot for all features
plt.style.use('ggplot')
df_copy.hist(bins=50,figsize=(20,15))
plt.show()

# %%
# correlation heatmap with annotation
plt.figure(figsize=(12,10))
sns.heatmap(df_copy.corr(),cmap='plasma',annot=True)
plt.title("Correlation Heatmap for forest fire | Both Region")
plt.show()

# %%
#Boxplot for target variable
plt.boxplot(df_copy['FWI'])
plt.show()

# %%
df['Classes'] = np.where(df['Classes'].str.contains('not fire'),'not fire','fire')

# %%
# Monthly based forest fire trend

dftemp  = df.loc[df['Region']==1]
plt.subplots(figsize=(13,6))
sns.set_style('whitegrid')
plt.title("Forest fire trend by month in Bejaia region")
plt.xlabel("Month",weight="bold")
plt.ylabel("Fires count",weight="bold")
sns.countplot(x='month',hue='Classes',data=df)
# Out:
# <Axes: title={'center': 'Forest fire trend by month in Bejaia region'}, xlabel='Month', ylabel='Fires count'>

# %%
# Monthly based forest fire trend

dftemp  = df.loc[df['Region']==0]
plt.subplots(figsize=(13,6))
sns.set_style('whitegrid')
plt.title("Forest fire trend by month in Sidi-Bel-abbes region")
plt.xlabel("Month",weight="bold")
plt.ylabel("Fires count",weight="bold")
sns.countplot(x='month',hue='Classes',palette='dark:Green',data=df)
# Out:
# <Axes: title={'center': 'Forest fire trend by month in Sidi-Bel-abbes region'}, xlabel='Month', ylabel='Fires count'>

# %% [markdown]
# # Feature Selection

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
cleaned_df = pd.read_csv("fires_dataset_cleaned.csv")

# %%
# dropping month day and year
cleaned_df=cleaned_df.drop(['day','month','year'],axis=1)

# %%
cleaned_df['Classes'] = np.where(cleaned_df['Classes'].str.contains('not fire'),0,1)

# %%
# Independent and dependent 
X = cleaned_df.drop('FWI',axis=1)
y = cleaned_df['FWI']

# %%
# Train, test, split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state = 4)

# %%
X_train.shape,X_test.shape
# Out:
# ((182, 11), (61, 11))

# %%
# Feature selection based on correlation

#Check multi collinearity
plt.figure(figsize=(12,10))
corr=X_train.corr()
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
def correlation(dataset,thresold):
    col_corr = set()
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i,j])> thresold:
                colname = corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
# thresold - should be set by domain expert
corr_features = correlation(X_train,0.85)
corr_features
# Out:
# {'BUI', 'DC'}

# %%
# drop features when correlation is more than 0.85
X_train = X_train.drop(corr_features,axis=1)
X_test = X_test.drop(corr_features,axis=1)

# %%
X_train.shape,X_test.shape
# Out:
# ((182, 9), (61, 9))

# %% [markdown]
# # Feature Scaling / Standarizing

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[-0.91262417, -0.29012494, -0.50080191, ...,  0.69296783,
#          0.84674738, -1.03352882],
#        [-0.63671454, -0.48617472, -0.50080191, ..., -0.83618894,
#         -1.18098977,  0.96755889],
#        [ 0.466924  ,  0.55942409,  0.20575582, ...,  0.1283561 ,
#          0.84674738,  0.96755889],
#        ...,
#        [ 2.1223818 , -1.79317323, -0.50080191, ...,  2.10449715,
#          0.84674738,  0.96755889],
#        [ 0.19101436,  0.10197461,  0.55903469, ..., -0.76561247,
#         -1.18098977,  0.96755889],
#        [-0.08489527,  0.62477401, -1.20735964, ..., -1.00086736,
#         -1.18098977,  0.96755889]], shape=(182, 9))

# %%
# Box plots to understand effect of Standard Scaler

plt.subplots(figsize=(25,10))
plt.subplot(1,2,1)
sns.boxplot(data=X_train)
plt.title("X_train before scaling")
plt.subplot(1,2,2)
sns.boxplot(data=X_train_scaled)
plt.title("X_train After scaling")
# Out:
# Text(0.5, 1.0, 'X_train After scaling')

# %% [markdown]
# # Model Training

# %%
# Linear Regression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

linearg = LinearRegression()
linearg.fit(X_train_scaled,y_train)
y_pred = linearg.predict(X_test_scaled)
mae = mean_absolute_error(y_test,y_pred)
score = r2_score(y_test,y_pred)

print(f"MAE: {mae}")
print(f"R2 score: {score}")

plt.scatter(y_test, y_pred)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='green', linestyle='--')  # identity line
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted")
plt.grid(True)
plt.show()
# Out:
# MAE: 0.6778288687520768
# R2 score: 0.9836634530297976

# %%
#Lasso Regression
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

lasso = Lasso()
lasso.fit(X_train_scaled,y_train)
y_pred = lasso.predict(X_test_scaled)
mae = mean_absolute_error(y_test,y_pred)
score = r2_score(y_test,y_pred)

print(f"MAE: {mae}")
print(f"R2 score: {score}")

plt.scatter(y_test, y_pred)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='pink', linestyle='-')  # identity line
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted")
plt.grid(True)
plt.show()
# Out:
# MAE: 1.3250281717391894
# R2 score: 0.9391536149835098

# %%
from sklearn.linear_model import LassoCV
lassoCV = LassoCV(cv=5)
lassoCV.fit(X_train_scaled,y_train)
y_pred=lassoCV.predict(X_test_scaled)

# %%
plt.scatter(y_test,y_pred)

# %%
#Ridge Regression

from sklearn.linear_model import Ridge
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

ridge = Ridge()
ridge.fit(X_train_scaled,y_train)
y_pred = ridge.predict(X_test_scaled)
mae = mean_absolute_error(y_test,y_pred)
score = r2_score(y_test,y_pred)

print(f"MAE: {mae}")
print(f"R2 score: {score}")

plt.scatter(y_test, y_pred)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='purple', linestyle='-')  # identity line
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted")
plt.grid(True)
plt.show()
# Out:
# MAE: 0.6945660040306056
# R2 score: 0.9829919664016085

# %%
from sklearn.linear_model import RidgeCV
ridgecv = RidgeCV(cv=5)
ridgecv.fit(X_train_scaled,y_train)
y_pred = ridgecv.predict(X_test_scaled)
plt.scatter(y_pred,y_test)

# %%
#ElasticNet

from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

elastic = ElasticNet()
elastic.fit(X_train_scaled,y_train)
y_pred = elastic.predict(X_test_scaled)
mae = mean_absolute_error(y_test,y_pred)
score = r2_score(y_test,y_pred)

print(f"MAE: {mae}")
print(f"R2 score: {score}")

plt.scatter(y_test, y_pred)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='black', linestyle='-')  # identity line
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted")
plt.grid(True)
plt.show()
# Out:
# MAE: 1.8554421576312397
# R2 score: 0.882388680753389

# %%
from sklearn.linear_model import ElasticNetCV
elasticv = ElasticNetCV(cv=5)
elasticv.fit(X_train_scaled,y_train)
y_pred = ridgecv.predict(X_test_scaled)
plt.scatter(y_pred,y_test)

# %%
elasticv.alphas_
# Out:
# array([13.53127417, 12.61931158, 11.76881221, 10.97563366, 10.23591269,
#         9.54604643,  8.90267485,  8.30266436,  7.74309257,  7.22123405,
#         6.73454704,  6.28066111,  5.85736557,  5.46259874,  5.09443786,
#         4.7510898 ,  4.43088225,  4.13225562,  3.85375542,  3.5940252 ,
#         3.35179993,  3.12589983,  2.91522465,  2.71874826,  2.53551373,
#         2.36462859,  2.20526054,  2.05663336,  1.91802315,  1.78875481,
#         1.66819872,  1.55576771,  1.45091418,  1.35312742,  1.26193116,
#         1.17688122,  1.09756337,  1.02359127,  0.95460464,  0.89026748,
#         0.83026644,  0.77430926,  0.7221234 ,  0.6734547 ,  0.62806611,
#         0.58573656,  0.54625987,  0.50944379,  0.47510898,  0.44308823,
#         0.41322556,  0.38537554,  0.35940252,  0.33517999,  0.31258998,
#         0.29152246,  0.27187483,  0.25355137,  0.23646286,  0.22052605,
#         0.20566334,  0.19180232,  0.17887548,  0.16681987,  0.15557677,
# ...
