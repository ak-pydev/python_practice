# %% [markdown]
# # Sample mlflow project

# %%
import pandas as pd
import numpy as np
from sklearn import datasets
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import mlflow
from mlflow.models import infer_signature
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 7
#       5 from sklearn.metrics import accuracy_score
#       6 from sklearn.model_selection import train_test_split
# ----> 7 import mlflow
#       8 from mlflow.models import infer_signature
#
# ModuleNotFoundError: No module named 'mlflow'

# %%
#loading the dataset

X,y= datasets.load_iris(return_X_y=True)

#splitting the data into train test
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.20)

#definig hyper parameters
params = {"penalty":"l2","solver": "lbfgs","max_iter":1000,"multi_class":"auto","random_state":8888}

# %%
#Train the model

lrm = LogisticRegression(**params)
lrm.fit(X_train,y_train)
# Out:
# /Users/aadityakhanal/Library/Caches/pypoetry/virtualenvs/learn-py-LEcJ1As4-py3.12/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# LogisticRegression(max_iter=1000, multi_class='auto', random_state=8888)

# %%
y_pred = lrm.predict(X_test)
y_pred
# Out:
# array([2, 2, 1, 0, 2, 0, 0, 0, 2, 2, 2, 0, 1, 2, 0, 2, 2, 2, 1, 1, 0, 2,
#        0, 2, 0, 0, 1, 1, 1, 1])

# %%
accuracy = accuracy_score(y_test,y_pred)

# %%
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9

# %% [markdown]
# # MLFlow Track and Log

# %%
mlflow.set_tracking_uri(uri="http://127.0.0.1:5000")

# %%
#create mlflow experiment

mlflow.set_experiment("Iris model performance tracking")

# start an mlflow log
with mlflow.start_run():
    #logging the hyperparameters
    mlflow.log_params(params)
    mlflow.log_metric("accuracy",accuracy)
    
    # Setting a tag as a reminder for understanding why this was run.
    mlflow.set_tag("Training info","Simple LR model for iris data")

    # Infering the model signature
    signature = infer_signature(X_train,lrm.predict(X_train))

    # logging the model
    model_info = mlflow.sklearn.log_model(sk_model=lrm,
                                          artifact_path="iris_model",
                                          signature=signature,
                                          input_example = X_train,
                                          registered_model_name="tracking-quickstart")
# Out:
# 2025/06/11 15:50:16 INFO mlflow.tracking.fluent: Experiment with name 'Iris model performance tracking' does not exist. Creating a new experiment.
# Registered model 'tracking-quickstart' already exists. Creating a new version of this model...
# 2025/06/11 15:50:18 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: tracking-quickstart, version 1
# 🏃 View run gaudy-wolf-450 at: http://127.0.0.1:5000/#/experiments/854348038609202012/runs/549e89d31a084b31ba7910ac444b3952
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/854348038609202012
# Created version '1' of model 'tracking-quickstart'.

# %% [markdown]
# # Inferencing Model Artifacts with MLFlow inferencing / Validating model

# %%
model_uri = model_info.model_uri
model_uri
# Out:
# 'runs:/549e89d31a084b31ba7910ac444b3952/iris_model'

# %%
from mlflow.models import validate_serving_input

serving_payload = """
 {
  "inputs": [
    [
      5,
      2.3,
      3.3,
      1
    ],
    [
      5.7,
      3,
      4.2,
      1.2
    ],
    [
      6.4,
      2.8,
      5.6,
      2.1
    ],
    [
      4.9,
      3.6,
      1.4,
      0.1
    ],
    [
      6.4,
      2.7,
      5.3,
      1.9
    ],
    [
      5.7,
      2.8,
      4.1,
      1.3
    ],
    [
      7.2,
      3.2,
      6,
      1.8
    ],
    [
      5.7,
      3.8,
      1.7,
      0.3
    ],
    [
      5.7,
      2.6,
      3.5,
      1
    ],
    [
      6.2,
      3.4,
      5.4,
      2.3
    ],
    [
      4.4,
      3,
      1.3,
      0.2
    ],
    [
      5.4,
      3.9,
      1.7,
      0.4
    ],
    [
      6.7,
      3,
      5,
      1.7
    ],
    [
      4.3,
      3,
      1.1,
      0.1
    ],
    [
      6.9,
      3.2,
      5.7,
      2.3
    ],
    [
      5.3,
      3.7,
      1.5,
      0.2
    ],
    [
      6.3,
      2.5,
      5,
      1.9
    ],
    [
      7.7,
      2.6,
      6.9,
      2.3
    ],
    [
      6.1,
      2.8,
      4,
      1.3
    ],
    [
      4.4,
      3.2,
      1.3,
      0.2
    ],
    [
      4.5,
      2.3,
      1.3,
      0.3
    ],
    [
      6.1,
      2.8,
      4.7,
      1.2
    ],
    [
      6.1,
      3,
      4.6,
      1.4
    ],
    [
      6.8,
      2.8,
      4.8,
      1.4
    ],
    [
      6.5,
      3,
      5.5,
      1.8
    ],
    [
      5.1,
      3.8,
      1.9,
      0.4
    ],
    [
      6.3,
      3.3,
      4.7,
      1.6
    ],
    [
      5.9,
      3.2,
      4.8,
      1.8
    ],
    [
      4.7,
      3.2,
      1.6,
      0.2
    ],
    [
      6.7,
      3.3,
      5.7,
      2.5
    ],
    [
      5,
      2,
      3.5,
      1
    ],
    [
      6.4,
      2.9,
      4.3,
      1.3
    ],
    [
      5.7,
      2.9,
      4.2,
      1.3
    ],
    [
      4.4,
      2.9,
      1.4,
      0.2
    ],
    [
      5.6,
      2.5,
      3.9,
      1.1
    ],
    [
      4.7,
      3.2,
      1.3,
      0.2
    ],
    [
      5.7,
      2.5,
      5,
      2
    ],
    [
      6.6,
      2.9,
      4.6,
      1.3
    ],
    [
      6.7,
      2.5,
      5.8,
      1.8
    ],
    [
      5.6,
      2.8,
      4.9,
      2
    ],
    [
      6.6,
      3,
      4.4,
      1.4
    ],
    [
      6.9,
      3.1,
      4.9,
      1.5
    ],
    [
      5.2,
      3.4,
      1.4,
      0.2
    ],
    [
      5.5,
      2.5,
      4,
      1.3
    ],
    [
      4.8,
      3,
      1.4,
      0.1
    ],
    [
      6,
      3,
      4.8,
      1.8
    ],
    [
      5.4,
      3,
      4.5,
      1.5
    ],
    [
      5,
      3.4,
      1.5,
      0.2
    ],
    [
      6.4,
      2.8,
      5.6,
      2.2
    ],
    [
      5,
      3,
      1.6,
      0.2
    ],
    [
      5,
      3.5,
      1.6,
      0.6
    ],
    [
      5.5,
      2.4,
      3.8,
      1.1
    ],
    [
      6.1,
      2.6,
      5.6,
      1.4
    ],
    [
      5.4,
      3.9,
      1.3,
      0.4
    ],
    [
      6.7,
      3,
      5.2,
      2.3
    ],
    [
      5.1,
      3.3,
      1.7,
      0.5
    ],
    [
      5,
      3.5,
      1.3,
      0.3
    ],
    [
      5.6,
      2.9,
      3.6,
      1.3
    ],
    [
      6,
      2.2,
      4,
      1
    ],
    [
      5.5,
      4.2,
      1.4,
      0.2
    ],
    [
      6.2,
      2.2,
      4.5,
      1.5
    ],
    [
      7.7,
      3.8,
      6.7,
      2.2
    ],
    [
      5.1,
      3.5,
      1.4,
      0.2
    ],
    [
      7.9,
      3.8,
      6.4,
      2
    ],
    [
      6,
      2.9,
      4.5,
      1.5
    ],
    [
      5.8,
      2.7,
      5.1,
      1.9
    ],
    [
      5.9,
      3,
      5.1,
      1.8
    ],
    [
      4.6,
      3.1,
      1.5,
      0.2
    ],
    [
      6,
      2.2,
      5,
      1.5
    ],
    [
      4.6,
      3.4,
      1.4,
      0.3
    ],
    [
      5.5,
      3.5,
      1.3,
      0.2
    ],
    [
      6.9,
      3.1,
      5.4,
      2.1
    ],
    [
      6.1,
      3,
      4.9,
      1.8
    ],
    [
      4.9,
      3.1,
      1.5,
      0.1
    ],
    [
      6.7,
      3.3,
      5.7,
      2.1
    ],
    [
      4.8,
      3.4,
      1.9,
      0.2
    ],
    [
      5.8,
      2.8,
      5.1,
      2.4
    ],
    [
      5.6,
      2.7,
      4.2,
      1.3
    ],
    [
      5.1,
      3.7,
      1.5,
      0.4
    ],
    [
      5.5,
      2.6,
      4.4,
      1.2
    ],
    [
      5.4,
      3.7,
      1.5,
      0.2
    ],
    [
      6.3,
      3.4,
      5.6,
      2.4
    ],
    [
      5.9,
      3,
      4.2,
      1.5
    ],
    [
      4.9,
      2.4,
      3.3,
      1
    ],
    [
      5.7,
      2.8,
      4.5,
      1.3
    ],
    [
      7.2,
      3,
      5.8,
      1.6
    ],
    [
      5.1,
      3.8,
      1.5,
      0.3
    ],
    [
      7.7,
      3,
      6.1,
      2.3
    ],
    [
      5.5,
      2.3,
      4,
      1.3
    ],
    [
      4.8,
      3.4,
      1.6,
      0.2
    ],
    [
      5.8,
      2.6,
      4,
      1.2
    ],
    [
      5.8,
      2.7,
      3.9,
      1.2
    ],
    [
      5,
      3.2,
      1.2,
      0.2
    ],
    [
      6.4,
      3.2,
      4.5,
      1.5
    ],
    [
      5.2,
      3.5,
      1.5,
      0.2
    ],
    [
      6.7,
      3.1,
      4.4,
      1.4
    ],
    [
      7.2,
      3.6,
      6.1,
      2.5
    ],
    [
      6.8,
      3,
      5.5,
      2.1
    ],
    [
      6.2,
      2.9,
      4.3,
      1.3
    ],
    [
      5.1,
      3.4,
      1.5,
      0.2
    ],
    [
      7.3,
      2.9,
      6.3,
      1.8
    ],
    [
      4.9,
      3,
      1.4,
      0.2
    ],
    [
      5.4,
      3.4,
      1.5,
      0.4
    ],
    [
      5.1,
      3.5,
      1.4,
      0.3
    ],
    [
      7.4,
      2.8,
      6.1,
      1.9
    ],
    [
      6.7,
      3.1,
      4.7,
      1.5
    ],
    [
      5.1,
      3.8,
      1.6,
      0.2
    ],
    [
      5.4,
      3.4,
      1.7,
      0.2
    ],
    [
      4.8,
      3.1,
      1.6,
      0.2
    ],
    [
      6.5,
      2.8,
      4.6,
      1.5
    ],
    [
      6.3,
      2.9,
      5.6,
      1.8
    ],
    [
      6.3,
      2.3,
      4.4,
      1.3
    ],
    [
      6.9,
      3.1,
      5.1,
      2.3
    ],
    [
      5.1,
      2.5,
      3,
      1.1
    ],
    [
      6.1,
      2.9,
      4.7,
      1.4
    ],
    [
      7.1,
      3,
      5.9,
      2.1
    ],
    [
      7.6,
      3,
      6.6,
      2.1
    ],
    [
      6,
      3.4,
      4.5,
      1.6
    ],
    [
      6.3,
      3.3,
      6,
      2.5
    ],
    [
      5.2,
      2.7,
      3.9,
      1.4
    ]
  ]
}  
"""
validate_serving_input(model_uri,serving_payload)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from mlflow.models import validate_serving_input
#       3 serving_payload = """
#       4  {
#       5   "inputs": [
#    (...)
#     727 }
#     728 """
#     729 validate_serving_input(model_uri,serving_payload)
#
# ModuleNotFoundError: No module named 'mlflow'

# %%
loaded_model = mlflow.pyfunc.load_model(model_info.model_uri)
predictions = loaded_model.predict(X_test)

iris_feauture_name = datasets.load_iris().feature_names

result = pd.DataFrame(X_test,columns=iris_features_name)
result["actual_class"] = y_test
result["predicted_class"] = predictions

# %%
results
