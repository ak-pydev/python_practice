# %% [markdown]
# # Sample mlflow project

# %%
import pandas as pd
import numpy as np
from sklearn import datasets
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import mlflow
from mlflow.models import infer_signature

# %%
#loading the dataset

X,y= datasets.load_iris(return_X_y=True)

#splitting the data into train test
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.20)

#definig hyper parameters
params = {"penalty":"l2","solver": "lbfgs","max_iter":1000,"multi_class":"auto","random_state":8888}

# %%
#Train the model

lrm = LogisticRegression(**params)
lrm.fit(X_train,y_train)
# Out:
# /Users/aadityakhanal/Library/Caches/pypoetry/virtualenvs/learn-py-LEcJ1As4-py3.12/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# LogisticRegression(max_iter=1000, multi_class='auto', random_state=8888)

# %%
y_pred = lrm.predict(X_test)
y_pred
# Out:
# array([1, 0, 2, 2, 1, 2, 0, 2, 0, 1, 1, 2, 0, 0, 1, 2, 0, 2, 0, 1, 1, 0,
#        0, 2, 0, 2, 2, 1, 2, 0])

# %%
accuracy = accuracy_score(y_test,y_pred)

# %%
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9666666666666667

# %% [markdown]
# # MLFlow Track and Log

# %%
mlflow.set_tracking_uri(uri="http://127.0.0.1:5000")

# %%
#create mlflow experiment

mlflow.set_experiment("Iris model performance tracking")

# start an mlflow log
with mlflow.start_run():
    #logging the hyperparameters
    mlflow.log_params(params)
    mlflow.log_metric("accuracy",accuracy)
    
    # Setting a tag as a reminder for understanding why this was run.
    mlflow.set_tag("Training info","Simple LR model for iris data")

    # Infering the model signature
    signature = infer_signature(X_train,lrm.predict(X_train))

    # logging the model
    model_info = mlflow.sklearn.log_model(sk_model=lrm,
                                          artifact_path="iris_model",
                                          signature=signature,
                                          input_example = X_train,
                                          registered_model_name="tracking-quickstart")
# Out:
# Registered model 'tracking-quickstart' already exists. Creating a new version of this model...
# 2025/06/11 22:38:06 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: tracking-quickstart, version 3
# 🏃 View run chill-horse-101 at: http://127.0.0.1:5000/#/experiments/854348038609202012/runs/ffac49cab50740f09b41c371cfc690f0
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/854348038609202012
# Created version '3' of model 'tracking-quickstart'.

# %% [markdown]
# # Inferencing Model Artifacts with MLFlow inferencing / Validating model

# %%
model_uri = model_info.model_uri
model_uri
# Out:
# 'runs:/2642a97c388e4011a1374d8cb64fae49/iris_model'

# %%
from mlflow.models import validate_serving_input

serving_payload = """
 {
  "inputs": [
    [
      5,
      2.3,
      3.3,
      1
    ],
    [
      5.7,
      3,
      4.2,
      1.2
    ],
    [
      6.4,
      2.8,
      5.6,
      2.1
    ],
    [
      4.9,
      3.6,
      1.4,
      0.1
    ],
    [
      6.4,
      2.7,
      5.3,
      1.9
    ],
    [
      5.7,
      2.8,
      4.1,
      1.3
    ],
    [
      7.2,
      3.2,
      6,
      1.8
    ],
    [
      5.7,
      3.8,
      1.7,
      0.3
    ],
    [
      5.7,
      2.6,
      3.5,
      1
    ],
    [
      6.2,
      3.4,
      5.4,
      2.3
    ],
    [
      4.4,
      3,
      1.3,
      0.2
    ],
    [
      5.4,
      3.9,
      1.7,
      0.4
    ],
    [
      6.7,
      3,
      5,
      1.7
    ],
    [
      4.3,
      3,
      1.1,
      0.1
    ],
    [
      6.9,
      3.2,
      5.7,
      2.3
    ],
    [
      5.3,
      3.7,
      1.5,
      0.2
    ],
    [
      6.3,
      2.5,
      5,
      1.9
    ],
    [
      7.7,
      2.6,
      6.9,
      2.3
    ],
    [
      6.1,
      2.8,
      4,
      1.3
    ],
    [
      4.4,
      3.2,
      1.3,
      0.2
    ],
    [
      4.5,
      2.3,
      1.3,
      0.3
    ],
    [
      6.1,
      2.8,
      4.7,
      1.2
    ],
    [
      6.1,
      3,
      4.6,
      1.4
    ],
    [
      6.8,
      2.8,
      4.8,
      1.4
    ],
    [
      6.5,
      3,
      5.5,
      1.8
    ],
    [
      5.1,
      3.8,
      1.9,
      0.4
    ],
    [
      6.3,
      3.3,
      4.7,
      1.6
    ],
    [
      5.9,
      3.2,
      4.8,
      1.8
    ],
    [
      4.7,
      3.2,
      1.6,
      0.2
    ],
    [
      6.7,
      3.3,
      5.7,
      2.5
    ],
    [
      5,
      2,
      3.5,
      1
    ],
    [
      6.4,
      2.9,
      4.3,
      1.3
    ],
    [
      5.7,
      2.9,
      4.2,
      1.3
    ],
    [
      4.4,
      2.9,
      1.4,
      0.2
    ],
    [
      5.6,
      2.5,
      3.9,
      1.1
    ],
    [
      4.7,
      3.2,
      1.3,
      0.2
    ],
    [
      5.7,
      2.5,
      5,
      2
    ],
    [
      6.6,
      2.9,
      4.6,
      1.3
    ],
    [
      6.7,
      2.5,
      5.8,
      1.8
    ],
    [
      5.6,
      2.8,
      4.9,
      2
    ],
    [
      6.6,
      3,
      4.4,
      1.4
    ],
    [
      6.9,
      3.1,
      4.9,
      1.5
    ],
    [
      5.2,
      3.4,
      1.4,
      0.2
    ],
    [
      5.5,
      2.5,
      4,
      1.3
    ],
    [
      4.8,
      3,
      1.4,
      0.1
    ],
    [
      6,
      3,
      4.8,
      1.8
    ],
    [
      5.4,
      3,
      4.5,
      1.5
    ],
    [
      5,
      3.4,
      1.5,
      0.2
    ],
    [
      6.4,
      2.8,
      5.6,
      2.2
    ],
    [
      5,
      3,
      1.6,
      0.2
    ],
    [
      5,
      3.5,
      1.6,
      0.6
    ],
    [
      5.5,
      2.4,
      3.8,
      1.1
    ],
    [
      6.1,
      2.6,
      5.6,
      1.4
    ],
    [
      5.4,
      3.9,
      1.3,
      0.4
    ],
    [
      6.7,
      3,
      5.2,
      2.3
    ],
    [
      5.1,
      3.3,
      1.7,
      0.5
    ],
    [
      5,
      3.5,
      1.3,
      0.3
    ],
    [
      5.6,
      2.9,
      3.6,
      1.3
    ],
    [
      6,
      2.2,
      4,
      1
    ],
    [
      5.5,
      4.2,
      1.4,
      0.2
    ],
    [
      6.2,
      2.2,
      4.5,
      1.5
    ],
    [
      7.7,
      3.8,
      6.7,
      2.2
    ],
    [
      5.1,
      3.5,
      1.4,
      0.2
    ],
    [
      7.9,
      3.8,
      6.4,
      2
    ],
    [
      6,
      2.9,
      4.5,
      1.5
    ],
    [
      5.8,
      2.7,
      5.1,
      1.9
    ],
    [
      5.9,
      3,
      5.1,
      1.8
    ],
    [
      4.6,
      3.1,
      1.5,
      0.2
    ],
    [
      6,
      2.2,
      5,
      1.5
    ],
    [
      4.6,
      3.4,
      1.4,
      0.3
    ],
    [
      5.5,
      3.5,
      1.3,
      0.2
    ],
    [
      6.9,
      3.1,
      5.4,
      2.1
    ],
    [
      6.1,
      3,
      4.9,
      1.8
    ],
    [
      4.9,
      3.1,
      1.5,
      0.1
    ],
    [
      6.7,
      3.3,
      5.7,
      2.1
    ],
    [
      4.8,
      3.4,
      1.9,
      0.2
    ],
    [
      5.8,
      2.8,
      5.1,
      2.4
    ],
    [
      5.6,
      2.7,
      4.2,
      1.3
    ],
    [
      5.1,
      3.7,
      1.5,
      0.4
    ],
    [
      5.5,
      2.6,
      4.4,
      1.2
    ],
    [
      5.4,
      3.7,
      1.5,
      0.2
    ],
    [
      6.3,
      3.4,
      5.6,
      2.4
    ],
    [
      5.9,
      3,
      4.2,
      1.5
    ],
    [
      4.9,
      2.4,
      3.3,
      1
    ],
    [
      5.7,
      2.8,
      4.5,
      1.3
    ],
    [
      7.2,
      3,
      5.8,
      1.6
    ],
    [
      5.1,
      3.8,
      1.5,
      0.3
    ],
    [
      7.7,
      3,
      6.1,
      2.3
    ],
    [
      5.5,
      2.3,
      4,
      1.3
    ],
    [
      4.8,
      3.4,
      1.6,
      0.2
    ],
    [
      5.8,
      2.6,
      4,
      1.2
    ],
    [
      5.8,
      2.7,
      3.9,
      1.2
    ],
    [
      5,
      3.2,
      1.2,
      0.2
    ],
    [
      6.4,
      3.2,
      4.5,
      1.5
    ],
    [
      5.2,
      3.5,
      1.5,
      0.2
    ],
    [
      6.7,
      3.1,
      4.4,
      1.4
    ],
    [
      7.2,
      3.6,
      6.1,
      2.5
    ],
    [
      6.8,
      3,
      5.5,
      2.1
    ],
    [
      6.2,
      2.9,
      4.3,
      1.3
    ],
    [
      5.1,
      3.4,
      1.5,
      0.2
    ],
    [
      7.3,
      2.9,
      6.3,
      1.8
    ],
    [
      4.9,
      3,
      1.4,
      0.2
    ],
    [
      5.4,
      3.4,
      1.5,
      0.4
    ],
    [
      5.1,
      3.5,
      1.4,
      0.3
    ],
    [
      7.4,
      2.8,
      6.1,
      1.9
    ],
    [
      6.7,
      3.1,
      4.7,
      1.5
    ],
    [
      5.1,
      3.8,
      1.6,
      0.2
    ],
    [
      5.4,
      3.4,
      1.7,
      0.2
    ],
    [
      4.8,
      3.1,
      1.6,
      0.2
    ],
    [
      6.5,
      2.8,
      4.6,
      1.5
    ],
    [
      6.3,
      2.9,
      5.6,
      1.8
    ],
    [
      6.3,
      2.3,
      4.4,
      1.3
    ],
    [
      6.9,
      3.1,
      5.1,
      2.3
    ],
    [
      5.1,
      2.5,
      3,
      1.1
    ],
    [
      6.1,
      2.9,
      4.7,
      1.4
    ],
    [
      7.1,
      3,
      5.9,
      2.1
    ],
    [
      7.6,
      3,
      6.6,
      2.1
    ],
    [
      6,
      3.4,
      4.5,
      1.6
    ],
    [
      6.3,
      3.3,
      6,
      2.5
    ],
    [
      5.2,
      2.7,
      3.9,
      1.4
    ]
  ]
}  
"""
validate_serving_input(model_uri,serving_payload)
# Out:
# Downloading artifacts:   0%|          | 0/7 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# Cell In[10], line 729
#       1 from mlflow.models import validate_serving_input
#       3 serving_payload = """
#       4  {
#       5   "inputs": [
#    (...)    727 }
#     728 """
# --> 729 validate_serving_input(model_uri,serving_payload)
#
# File ~/Library/Caches/pypoetry/virtualenvs/learn-py-LEcJ1As4-py3.12/lib/python3.12/site-packages/mlflow/models/utils.py:2006, in validate_serving_input(model_uri, serving_input)
#    2003 output_dir = None if get_local_path_or_none(model_uri) else create_tmp_dir()
#    2005 try:
# -> 2006     pyfunc_model = mlflow.pyfunc.load_model(model_uri, dst_path=output_dir)
#    2007     parsed_input = _parse_json_data(
#    2008         serving_input,
#    2009         pyfunc_model.metadata,
#    2010         pyfunc_model.metadata.get_input_schema(),
#    2011     )
#    2012     with _simulate_serving_environment():
#
# File ~/Library/Caches/pypoetry/virtualenvs/learn-py-LEcJ1As4-py3.12/lib/python3.12/site-packages/mlflow/tracing/provider.py:422, in trace_disabled.<locals>.wrapper(*args, **kwargs)
#     420 disable()
#     421 try:
# --> 422     is_func_called, result = True, f(*args, **kwargs)
#     423 finally:
#     424     enable()
#
# File ~/Library/Caches/pypoetry/virtualenvs/learn-py-LEcJ1As4-py3.12/lib/python3.12/site-packages/mlflow/pyfunc/__init__.py:1099, in load_model(model_uri, suppress_warnings, dst_path, model_config)
#    1095         entity_list.append(Entity(job=job_entity))
#    1097     lineage_header_info = LineageHeaderInfo(entities=entity_list) if entity_list else None
# -> 1099 local_path = _download_artifact_from_uri(
#    1100     artifact_uri=model_uri, output_path=dst_path, lineage_header_info=lineage_header_info
#    1101 )
#    1103 if not suppress_warnings:
#    1104     model_requirements = _get_pip_requirements_from_model_path(local_path)
#
# File ~/Library/Caches/pypoetry/virtualenvs/learn-py-LEcJ1As4-py3.12/lib/python3.12/site-packages/mlflow/tracking/artifact_utils.py:116, in _download_artifact_from_uri(artifact_uri, output_path, lineage_header_info)
#     110 if isinstance(repo, ModelsArtifactRepository):
#     111     return repo.download_artifacts(
#     112         artifact_path=artifact_path,
#     113         dst_path=output_path,
#     114         lineage_header_info=lineage_header_info,
#     115     )
# --> 116 return repo.download_artifacts(artifact_path=artifact_path, dst_path=output_path)
#
# File ~/Library/Caches/pypoetry/virtualenvs/learn-py-LEcJ1As4-py3.12/lib/python3.12/site-packages/mlflow/store/artifact/runs_artifact_repo.py:131, in RunsArtifactRepository.download_artifacts(self, artifact_path, dst_path)
#     114 def download_artifacts(self, artifact_path, dst_path=None):
#     115     """
#     116     Download an artifact file or directory to a local directory if applicable, and return a
#     117     local path for it.
#    (...)    129         Absolute path of the local filesystem location containing the desired artifacts.
#     130     """
# --> 131     return self.repo.download_artifacts(artifact_path, dst_path)
#
# File ~/Library/Caches/pypoetry/virtualenvs/learn-py-LEcJ1As4-py3.12/lib/python3.12/site-packages/mlflow/store/artifact/artifact_repo.py:317, in ArtifactRepository.download_artifacts(self, artifact_path, dst_path)
#     311         template = "##### File {path} #####\n{error}"
#     313     failures = "\n".join(
#     314         template.format(path=path, error=error, traceback=tracebacks[path])
#     315         for path, error in failed_downloads.items()
#     316     )
# --> 317     raise MlflowException(
#     318         message=(
#     319             "The following failures occurred while downloading one or more"
#     320             f" artifacts from {self.artifact_uri}:\n{_truncate_error(failures)}"
#     321         )
#     322     )
#     324 return os.path.join(dst_path, artifact_path)
#
# MlflowException: The following failures occurred while downloading one or more artifacts from http://127.0.0.1:5000/api/2.0/mlflow-artifacts/artifacts/854348038609202012/2642a97c388e4011a1374d8cb64fae49/artifacts:
# ##### File iris_model/python_env.yaml #####
# API request to http://127.0.0.1:5000/api/2.0/mlflow-artifacts/artifacts/854348038609202012/2642a97c388e4011a1374d8cb64fae49/artifacts/iris_model/python_env.yaml failed with exception HTTPConnectionPool(host='127.0.0.1', port=5000): Max retries exceeded with url: /api/2.0/mlflow-artifacts/artifacts/854348038609202012/2642a97c388e4011a1374d8cb64fae49/artifacts/iris_model/python_env.yaml (Caused by ResponseError('too many 500 error responses'))
# ##### File iris_model/conda.yaml #####
# API request to http://127.0.0.1:5000/api/2.0/mlflow-artifacts/artifacts/854348038609202012/2642a97c388e4011a1374d8cb64fae49/artifacts/iris_model/conda.yaml failed with exception HTTPConnectionPool(host='127.0.0.1', port=5000): Max retries exceeded with url: /api/2.0/mlflow-artifacts/artifacts/854348038609202012/2642a97c388e4011a1374d8cb64fae49/artifacts/iris_model/conda.yaml (Caused by ResponseError('too many 500 error responses'))
# ##### File iris_model/input_example.json #####
# API request to http://127.0.0.1:5000/api/2.0/mlflow-artifacts/artifacts/854348038609202012/2642a97c388e4011a1374d8cb64fae49/artifacts/iris_model/input_example.json failed with exception HTTPConnectionPool(host='127.0.0.1', port=5000): Max retries exceeded with url: /api/2.0/mlflow-artifacts/artifacts/854348038609202012/2642a97c388e4011a1374d8cb64fae49/artifacts/iris_model/input_example.json (Caused by ResponseError('too many 500 error responses'))
# ##### File iris_model/requirements.txt #####
# API request to http://127.0.0.1:5000/api/2.0/mlflow-artifacts/artifacts/854348038609202012/2642a97c388e4011a1374d8cb64fae49/artifacts/iris_model/requirements.txt failed with exception HTTPConnectionPool(host='127.0.0.1', port=5000): Max retries exceeded with url: /api/2.0/mlflow-artifacts/artifacts/854348038609202012/2642a97c388e4011a1374d8cb64fae49/artifacts/iris_model/requirements.txt (Caused by ResponseError('too many 500 error responses'))
# ##### File iris_model/model.pkl #####
# API request to http://127.0.0.1:5000/api/2.0/mlflow-artifacts/artifacts/854348038609202012/2642a97c388e4011a1374d8cb64fae49/artifacts/iris_model/model.pkl failed with exception HTTPConnectionPool(host='127.0.0.1', port=5000): Max retries exceeded with url: /api/2.0/mlflow-artifacts/artifacts/854348038609202012/2642a97c388e4011a1374d8cb64fae49/artifacts/iris_model/model.pkl (Caused by ResponseError('too many 500 error responses'))
# ##### File iris_model/MLmodel #####
# API request to http://127.0.0.1:5000/api/2.0/mlflow-artifacts/artifacts/854348038609202012/2642a97c388e4011a1374d8cb64fae49/artifacts/iris_model/MLmodel failed with exception HTTPConnectionPool(host='127.0.0.1', port=5000): Max retries exceeded with url: /api/2.0/mlflow-artifacts/artifacts/854348038609202012/2642a97c388e4011a1374d8cb64fae49/artifacts/iris_model/MLmodel (Caused by ResponseError('too many 500 error responses'))
# ##### File iris_model/serving_input_example.json #####
# API request to http://127.0.0.1:5000/api/2.0/mlflow-artifacts/artifacts/854348038609202012/2642a97c388e4011a1374d8cb64fae49/artifacts/iris_model/serving_input_example.json failed with exception HTTPConnectionPool(host='127.0.0.1', port=5000): Max retries exceeded with url: /api/2.0/mlflow-artifacts/artifacts/854348038609202012/2642a97c388e4011a1374d8cb64fae49/artifacts/iris_model/serving_input_example.json (Caused by ResponseError('too many 500 error responses'))

# %%
loaded_model = mlflow.pyfunc.load_model(model_info.model_uri)
predictions = loaded_model.predict(X_test)

iris_feauture_name = datasets.load_iris().feature_names

result = pd.DataFrame(X_test,columns=iris_features_name)
result["actual_class"] = y_test
result["predicted_class"] = predictions

# %%
results

# %% [markdown]
# # MLFlow Model Registry Tracking Manually

# %%
#create mlflow experiment

mlflow.set_experiment("Iris model performance tracking")

# start an mlflow log
with mlflow.start_run():
    #logging the hyperparameters
    mlflow.log_params(params)
    mlflow.log_metric("accuracy",1.0) # hard coded accuracy
    
    # Setting a tag as a reminder for understanding why this was run.
    mlflow.set_tag("Training info 2","Simple LR model for iris data")

    # Infering the model signature
    signature = infer_signature(X_train,lrm.predict(X_train))

    # logging the model
    model_info = mlflow.sklearn.log_model(sk_model=lrm,
                                          artifact_path="iris_model",
                                          signature=signature,
                                          input_example = X_train
                                          ) # here register model name parameter is missing
# Out:
# 🏃 View run suave-hog-408 at: http://127.0.0.1:5000/#/experiments/854348038609202012/runs/4b0bc5a94c2343f4a839b6ec67a3f377
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/854348038609202012

# %% [markdown]
# # Inferening the model from the model registry

# %%
import mlflow.sklearn
model_name = "tracking-quickstart"
model_version = "latest"
model_uri = f"models:/{model_name}/{model_version}"

model = mlflow.sklearn.load_model(model_uri)
# Out:
# Downloading artifacts:   0%|          | 0/7 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# Cell In[14], line 6
#       3 model_version = "latest"
#       4 model_uri = f"models:/{model_name}/{model_version}"
# ----> 6 model = mlflow.sklearn.load_model(model_uri)
#
# File ~/Library/Caches/pypoetry/virtualenvs/learn-py-LEcJ1As4-py3.12/lib/python3.12/site-packages/mlflow/sklearn/__init__.py:633, in load_model(model_uri, dst_path)
#     598 def load_model(model_uri, dst_path=None):
#     599     """
#     600     Load a scikit-learn model from a local file or a run.
#     601
#    (...)    631         predictions = sk_model.predict(pandas_df)
#     632     """
# --> 633     local_model_path = _download_artifact_from_uri(artifact_uri=model_uri, output_path=dst_path)
#     634     flavor_conf = _get_flavor_configuration(model_path=local_model_path, flavor_name=FLAVOR_NAME)
#     635     _add_code_from_conf_to_system_path(local_model_path, flavor_conf)
#
# File ~/Library/Caches/pypoetry/virtualenvs/learn-py-LEcJ1As4-py3.12/lib/python3.12/site-packages/mlflow/tracking/artifact_utils.py:111, in _download_artifact_from_uri(artifact_uri, output_path, lineage_header_info)
#     108 repo = get_artifact_repository(artifact_uri=root_uri)
#     110 if isinstance(repo, ModelsArtifactRepository):
# --> 111     return repo.download_artifacts(
#     112         artifact_path=artifact_path,
#     113         dst_path=output_path,
#     114         lineage_header_info=lineage_header_info,
#     115     )
#     116 return repo.download_artifacts(artifact_path=artifact_path, dst_path=output_path)
#
# File ~/Library/Caches/pypoetry/virtualenvs/learn-py-LEcJ1As4-py3.12/lib/python3.12/site-packages/mlflow/store/artifact/models_artifact_repo.py:210, in ModelsArtifactRepository.download_artifacts(self, artifact_path, dst_path, lineage_header_info)
#     206     model_path = self.repo.download_artifacts(
#     207         artifact_path, dst_path, lineage_header_info=lineage_header_info
#     208     )
#     209 else:
# --> 210     model_path = self.repo.download_artifacts(artifact_path, dst_path)
#     211 # NB: only add the registered model metadata iff the artifact path is at the root model
#     212 # directory. For individual files or subdirectories within the model directory, do not
#     213 # create the metadata file.
#     214 if os.path.isdir(model_path) and MLMODEL_FILE_NAME in os.listdir(model_path):
#
# File ~/Library/Caches/pypoetry/virtualenvs/learn-py-LEcJ1As4-py3.12/lib/python3.12/site-packages/mlflow/store/artifact/artifact_repo.py:317, in ArtifactRepository.download_artifacts(self, artifact_path, dst_path)
#     311         template = "##### File {path} #####\n{error}"
#     313     failures = "\n".join(
#     314         template.format(path=path, error=error, traceback=tracebacks[path])
#     315         for path, error in failed_downloads.items()
#     316     )
# --> 317     raise MlflowException(
#     318         message=(
#     319             "The following failures occurred while downloading one or more"
#     320             f" artifacts from {self.artifact_uri}:\n{_truncate_error(failures)}"
#     321         )
#     322     )
#     324 return os.path.join(dst_path, artifact_path)
#
# MlflowException: The following failures occurred while downloading one or more artifacts from http://127.0.0.1:5000/api/2.0/mlflow-artifacts/artifacts/854348038609202012/4b0bc5a94c2343f4a839b6ec67a3f377/artifacts/iris_model:
# ##### File conda.yaml #####
# API request to http://127.0.0.1:5000/api/2.0/mlflow-artifacts/artifacts/854348038609202012/4b0bc5a94c2343f4a839b6ec67a3f377/artifacts/iris_model/conda.yaml failed with exception HTTPConnectionPool(host='127.0.0.1', port=5000): Max retries exceeded with url: /api/2.0/mlflow-artifacts/artifacts/854348038609202012/4b0bc5a94c2343f4a839b6ec67a3f377/artifacts/iris_model/conda.yaml (Caused by ResponseError('too many 500 error responses'))
# ##### File serving_input_example.json #####
# API request to http://127.0.0.1:5000/api/2.0/mlflow-artifacts/artifacts/854348038609202012/4b0bc5a94c2343f4a839b6ec67a3f377/artifacts/iris_model/serving_input_example.json failed with exception HTTPConnectionPool(host='127.0.0.1', port=5000): Max retries exceeded with url: /api/2.0/mlflow-artifacts/artifacts/854348038609202012/4b0bc5a94c2343f4a839b6ec67a3f377/artifacts/iris_model/serving_input_example.json (Caused by ResponseError('too many 500 error responses'))
# ##### File requirements.txt #####
# API request to http://127.0.0.1:5000/api/2.0/mlflow-artifacts/artifacts/854348038609202012/4b0bc5a94c2343f4a839b6ec67a3f377/artifacts/iris_model/requirements.txt failed with exception HTTPConnectionPool(host='127.0.0.1', port=5000): Max retries exceeded with url: /api/2.0/mlflow-artifacts/artifacts/854348038609202012/4b0bc5a94c2343f4a839b6ec67a3f377/artifacts/iris_model/requirements.txt (Caused by ResponseError('too many 500 error responses'))
# ##### File input_example.json #####
# API request to http://127.0.0.1:5000/api/2.0/mlflow-artifacts/artifacts/854348038609202012/4b0bc5a94c2343f4a839b6ec67a3f377/artifacts/iris_model/input_example.json failed with exception HTTPConnectionPool(host='127.0.0.1', port=5000): Max retries exceeded with url: /api/2.0/mlflow-artifacts/artifacts/854348038609202012/4b0bc5a94c2343f4a839b6ec67a3f377/artifacts/iris_model/input_example.json (Caused by ResponseError('too many 500 error responses'))
# ##### File python_env.yaml #####
# API request to http://127.0.0.1:5000/api/2.0/mlflow-artifacts/artifacts/854348038609202012/4b0bc5a94c2343f4a839b6ec67a3f377/artifacts/iris_model/python_env.yaml failed with exception HTTPConnectionPool(host='127.0.0.1', port=5000): Max retries exceeded with url: /api/2.0/mlflow-artifacts/artifacts/854348038609202012/4b0bc5a94c2343f4a839b6ec67a3f377/artifacts/iris_model/python_env.yaml (Caused by ResponseError('too many 500 error responses'))
# ##### File MLmodel #####
# API request to http://127.0.0.1:5000/api/2.0/mlflow-artifacts/artifacts/854348038609202012/4b0bc5a94c2343f4a839b6ec67a3f377/artifacts/iris_model/MLmodel failed with exception HTTPConnectionPool(host='127.0.0.1', port=5000): Max retries exceeded with url: /api/2.0/mlflow-artifacts/artifacts/854348038609202012/4b0bc5a94c2343f4a839b6ec67a3f377/artifacts/iris_model/MLmodel (Caused by ResponseError('too many 500 error responses'))
# ##### File model.pkl #####
# API request to http://127.0.0.1:5000/api/2.0/mlflow-artifacts/artifacts/854348038609202012/4b0bc5a94c2343f4a839b6ec67a3f377/artifacts/iris_model/model.pkl failed with exception HTTPConnectionPool(host='127.0.0.1', port=5000): Max retries exceeded with url: /api/2.0/mlflow-artifacts/artifacts/854348038609202012/4b0bc5a94c2343f4a839b6ec67a3f377/artifacts/iris_model/model.pkl (Caused by ResponseError('too many 500 error responses'))

# %%
y_pred_new = model.predict(X_test)
y_pred_new
